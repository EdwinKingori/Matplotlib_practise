# %%
import csv 
import numpy as np
import pandas as pd
from collections import Counter 
from matplotlib import pyplot as plt

# %%
plt.style.use('fivethirtyeight')

# %%
df = pd.read_csv("data.csv")
df
# Out:
#        Responder_id                                LanguagesWorkedWith
# 0                 1                    HTML/CSS;Java;JavaScript;Python
# 1                 2                                C++;HTML/CSS;Python
# 2                 3                                           HTML/CSS
# 3                 4                                C;C++;C#;Python;SQL
# 4                 5        C++;HTML/CSS;Java;JavaScript;Python;SQL;VBA
# ...             ...                                                ...
# 87564         88182                           HTML/CSS;Java;JavaScript
# 87565         88212                         HTML/CSS;JavaScript;Python
# 87566         88282  Bash/Shell/PowerShell;Go;HTML/CSS;JavaScript;W...
# 87567         88377                      HTML/CSS;JavaScript;Other(s):
# 87568         88863  Bash/Shell/PowerShell;HTML/CSS;Java;JavaScript...
#
# [87569 rows x 2 columns]

# %%
column_names = list(df.columns)
print(column_names)
# Out:
# ['Responder_id', 'LanguagesWorkedWith']

# %% [markdown]
# ## Objective: plotting popular languages according the the data submitted.
#
# ### Using the csv module from the standard library to read the data.csv file and iterate through rows
#
# ### Using the built_in class Counters from the collections library to count the number of time each language has been used by the respondents.

# %%
with open ('data.csv') as csv_file:
    csv_reader = csv.DictReader(csv_file)
    
    language_counter = Counter ()
#getting/Counting data for all rows
    for row in csv_reader:
        language_counter.update(row['LanguagesWorkedWith'].split(';'))
        
print(language_counter)

# Printing the top most 15 used languages
print(language_counter.most_common(15))

#data for a single row
    #row = next(csv_reader)
    #print(row['LanguagesWorkedWith'].split(';'))
# Out:
# Counter({'JavaScript': 59219, 'HTML/CSS': 55466, 'SQL': 47544, 'Python': 36443, 'Java': 35917, 'Bash/Shell/PowerShell': 31991, 'C#': 27097, 'PHP': 23030, 'C++': 20524, 'TypeScript': 18523, 'C': 18017, 'Other(s):': 7920, 'Ruby': 7331, 'Go': 7201, 'Assembly': 5833, 'Swift': 5744, 'Kotlin': 5620, 'R': 5048, 'VBA': 4781, 'Objective-C': 4191, 'Scala': 3309, 'Rust': 2794, 'Dart': 1683, 'Elixir': 1260, 'Clojure': 1254, 'WebAssembly': 1015, 'F#': 973, 'Erlang': 777})
# [('JavaScript', 59219), ('HTML/CSS', 55466), ('SQL', 47544), ('Python', 36443), ('Java', 35917), ('Bash/Shell/PowerShell', 31991), ('C#', 27097), ('PHP', 23030), ('C++', 20524), ('TypeScript', 18523), ('C', 18017), ('Other(s):', 7920), ('Ruby', 7331), ('Go', 7201), ('Assembly', 5833)]

# %% [markdown]
# ## PLoting the data from the turple given of the top 15 most used languages.
# ### Step 1 : Using a for loop to split the languages into their own list, and the counts into their own list in order to put them into the x and y axis.
# ### Step 2: Plotting after assigning the x and y axis to languages and popularity

# %%
#Step 1
languages = []
popularity = []

for i in language_counter.most_common (15):
    languages.append(i[0])
    popularity.append(i[1])
    
print(languages)
print(popularity)
# Out:
# ['JavaScript', 'HTML/CSS', 'SQL', 'Python', 'Java', 'Bash/Shell/PowerShell', 'C#', 'PHP', 'C++', 'TypeScript', 'C', 'Other(s):', 'Ruby', 'Go', 'Assembly']
# [59219, 55466, 47544, 36443, 35917, 31991, 27097, 23030, 20524, 18523, 18017, 7920, 7331, 7201, 5833]

# %%
#Step 2: plotting
#using the reverse method to show the popular languages in desceding order

languages.reverse()
popularity.reverse()


plt.barh(languages, popularity) 

plt.title('The 15 Most Popular Langauages')
#plt.ylabel('Programming Langauages')
plt.xlabel('Number of users')

plt.tight_layout()
plt.grid(color= 'grey', linestyle = '-')
